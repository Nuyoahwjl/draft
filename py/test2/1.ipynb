# %%
import matplotlib.pyplot as plt
import numpy as np

# 在图中(0,0)到(6,250)之间画一条直线
xpoints = np.array([0, 6])
ypoints = np.array([6, 250])
plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# ### 这是一个示例
# - nihao
# ``` python
# print("hello")
# ```
#
# 这是 TeX Live 的下载链接：[TeX Live Download](https://www.tug.org/texlive/acquire.html)。在该页面中，你可以找到适合你操作系统的安装程序和说明。需要帮助时，请随时告诉我！
